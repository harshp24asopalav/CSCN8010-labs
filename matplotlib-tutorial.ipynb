# %% [markdown]
# # Matplotplib Tutorial

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

# Vertical lines
ax.plot([1, 1], [1, 3])
ax.plot([1.5, 1.5], [1, 3])

# Horizontal line
ax.plot([1, 2], [1.5, 2])
